# %%
#Importing the major libraries needed for web scraping
import requests
import re
import pandas as pd
from bs4 import BeautifulSoup as bso
# Out:
# /usr/local/lib/python3.5/dist-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.21.1) or chardet (2.3.0) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
class JumiaProduct(object):
    """
    This class parses the products section pages of jumia.com.ng,
    then it extracts some data such as the product names, prices, ratings, number of sales,
    links.
    
    You instantiate this class, by passing in a valid section link as a parameter as a string.
    
    The link should be the first page of section without having page number in the string:
    
    Correct: https://www.jumia.com.ng/mobile-phones/
             https://www.jumia.com.ng/beauty-corner/
             
    Wrong:   https://www.jumia.com.ng/mobile-phones/?page=1
             https://www.jumia.com.ng/beauty-corner/?page=1
    
    
    Example: JumiaProduct("https://www.jumia.com.ng/mobile-phones/")
    
    If link is wrong, it returns an InvalidLink error.
    
    It has the following methods:
    
       get_pages()
       get_links()
       get_prices()
       get_names()
       get_ratings()
       get_sales()  
    
    """
    
    def __init__(self, section_link):
        self.section_link = section_link
        self.pages = []
        self.names = []
        self.links = []
        self.prices = []
        self.ratings = []
        self.sales = []
        
    def get_pages():
        """
        
        This method is used to get the html pages of products from
        the section link provided.
        
        It returns a list of the html pages.
        
        """
        
    def get_links():
        """
        
        It takes in a list of html pages and parses them to get the link
        to every product.
        
        Example: 
        
        JumiaProduct("jumia.com.ng/example").get_links(["<html>.....</html>","<html>.....</html>"])
        
        It returns a list of the product links
        
        """
        
    def get_prices():
        """
        
        It takes in a list of html pages and parses them to get the price
        of every product.
        
        Example: 
        
        JumiaProduct("jumia.com.ng/example").get_links(["<html>.....</html>","<html>.....</html>"])
        
        It returns a list of the product prices
        
        """
    
    def get_names():
        """
        
        It takes in a list of html pages and parses them to get the name
        of every product.
        
        Example: 
        
        JumiaProduct("jumia.com.ng/example").get_links(["<html>.....</html>","<html>.....</html>"])
        
        It returns a list of the product names
        
        """
        
    def get_ratings():
        """
        
        It takes in a list of html pages and parses them to get the rating
        of every product.
        
        Example: 
        
        JumiaProduct("jumia.com.ng/example").get_links(["<html>.....</html>","<html>.....</html>"])
        
        It returns a list of the product ratings
        
        """
    
    def get_sales():
        """
        
        It takes in a list of html pages and parses them to get the number of sales
        of every product.
        
        Example: 
        
        JumiaProduct("jumia.com.ng/example").get_links(["<html>.....</html>","<html>.....</html>"])
        
        It returns a list of the product sales number
        
        """

# %%
ade = requests.get("https://www.jumia.com.ng/beauty-corner/")

# %%
ade = ade.content
ade_html = bso(ade, "html.parser")
print(ade_html.prettify())
# Out:
# <!DOCTYPE doctype html>
# <!--[if lt IE 7]>
# <html class="no-js ie6 oldie" lang="en-NG"> <![endif]-->
# <!--[if IE 7]>
# <html class="no-js ie7 oldie" lang="en-NG"> <![endif]-->
# <!--[if IE 8]>
# <html class="no-js ie8 oldie" lang="en-NG"> <![endif]-->
# <!--[if IE 9]>
# <html class="no-js ie9" lang="en-NG"> <![endif]-->
# <!--[if gt IE 9]><!-->
# <html class="no-js" lang="en-NG">
#  <!--<![endif]-->
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Health &amp; Beauty products - Buy Online | Jumia Nigeria
#   </title>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
#    <meta content="Discover health &amp; beauty products online at Jumia | Large selection of products for Skin care, Hair Care, Health, Fragrances &amp; more from top brands | Order Now!" name="description"/>
#    <meta content="" name="keywords"/>
#    <meta content="index,follow" name="robots"/>
# ...
